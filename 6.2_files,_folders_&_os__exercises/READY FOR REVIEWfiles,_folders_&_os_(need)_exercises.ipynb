# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %%
import os
import glob
import shutil
import numpy as np

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# Task 1

# %%
oldname=glob.glob('os-collaboration-exercise-data/**.txt')

months={'jan': '01', 'feb': '02', 'mar': '03',
        'apr': '04', 'may': '05', 'jun': '06',
        'jul': '07', 'aug': '08', 'sep': '09',
        'oct': '10', 'nov': '11', 'dec': '12'}

test=['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']

def rename_my_file(old_file_name):
    monthword,rest=old_file_name.split('-')
    rest=rest.replace("_","-")
    return f'{months[monthword]}-{rest}'

newname=[]
for i in range(len(test)):
    oldname=test[i]
    newname = rename_my_file(oldname)
    print(f'{oldname} ----> {newname}')
# Out:
# oct-08_singapore.txt ----> 10-08-singapore.txt
# jul-10_cairo.txt ----> 07-10-cairo.txt
# may-15_dhaka.txt ----> 05-15-dhaka.txt
# may-13_cairo.txt ----> 05-13-cairo.txt
# oct-21_cairo.txt ----> 10-21-cairo.txt
# jan-10_singapore.txt ----> 01-10-singapore.txt
# jun-20_tokyo.txt ----> 06-20-tokyo.txt
# aug-06_jakarta.txt ----> 08-06-jakarta.txt
# dec-21_karachi.txt ----> 12-21-karachi.txt
# jan-01_tokyo.txt ----> 01-01-tokyo.txt

# %% [markdown]
# Task 2

# %%
oldname=glob.glob('os-collaboration-exercise-data/**.txt')

months={'jan': '01', 'feb': '02', 'mar': '03',
        'apr': '04', 'may': '05', 'jun': '06',
        'jul': '07', 'aug': '08', 'sep': '09',
        'oct': '10', 'nov': '11', 'dec': '12'}

def rename_my_file(old_file_name):
    monthword,rest=old_file_name.split('-')
    rest=rest.replace("_","-")
    return f'{months[monthword]}-{rest}'

# %% [markdown]
# Task 3

# %%
example=['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']

months={'jan': '01', 'feb': '02', 'mar': '03',
        'apr': '04', 'may': '05', 'jun': '06',
        'jul': '07', 'aug': '08', 'sep': '09',
        'oct': '10', 'nov': '11', 'dec': '12'}

def rename_my_file(old_file_name):
    monthword,rest=old_file_name.split('-')
    rest=rest.replace("_","-")
    return f'{months[monthword]}-{rest}'

newname=[]
for i in range(len(example)):
    oldname=str(example[i])
    newname = rename_my_file(oldname)
    print(newname)

print(newname)
# Out:
# 10-08-singapore.txt
# 07-10-cairo.txt
# 05-15-dhaka.txt
# 05-13-cairo.txt
# 10-21-cairo.txt
# 01-10-singapore.txt
# 06-20-tokyo.txt
# 08-06-jakarta.txt
# 12-21-karachi.txt
# 01-01-tokyo.txt
# 01-01-tokyo.txt

# %% [markdown]
# Task 4

# %%
base_folder = r"C:\Users\PF3SC\OneDrive\Documents\GitHub\learning-portfolio-briana-tan\6.2_files,_folders_&_os__exercises\os-collaboration-exercise-data"

oldfiles = glob.glob(os.path.join(base_folder, "*.txt"))

months = {
    'jan': '01', 'feb': '02', 'mar': '03',
    'apr': '04', 'may': '05', 'jun': '06',
    'jul': '07', 'aug': '08', 'sep': '09',
    'oct': '10', 'nov': '11', 'dec': '12'
}

def rename_my_file(old_file_name):
    name, ext = os.path.splitext(old_file_name)
    monthword, rest = name.split('-')
    rest = rest.replace("_", "-")
    monthnumber = months[monthword]
    return f"{monthnumber}-{rest}{ext}"

newname=[]
for i in range(len(glob.glob('os-collaboration-exercise-data/**.txt'))):
    oldname=str(os.path.split(glob.glob('os-collaboration-exercise-data/**.txt')[i])[1])
    newname = rename_my_file(oldname)
    print(newname)

print(newname)
# Out:
# 04-01-melbourne.txt
# 04-01-shanghai.txt
# 04-01-singapore.txt
# 04-02-cairo.txt
# 04-02-jakarta.txt
# 04-02-karachi.txt
# 04-02-shanghai.txt
# 04-03-manila.txt
# 04-03-osaka.txt
# 04-03-singapore.txt
# 04-03-tokyo.txt
# 04-04-manila.txt
# 04-04-melbourne.txt
# 04-04-shanghai.txt
# 04-04-singapore.txt
# 04-05-karachi.txt
# 04-05-melbourne.txt
# 04-05-shanghai.txt
# 04-05-singapore.txt
# 04-06-cairo.txt
# 04-06-jakarta.txt
# 04-06-karachi.txt
# 04-06-manila.txt
# 04-07-cairo.txt
# 04-07-manila.txt
# 04-07-melbourne.txt
# 04-07-osaka.txt
# 04-07-singapore.txt
# 04-07-tokyo.txt
# 04-08-shanghai.txt
# 04-10-cairo.txt
# 04-10-manila.txt
# 04-10-melbourne.txt
# 04-10-shanghai.txt
# 04-10-singapore.txt
# 04-10-tokyo.txt
# 04-11-melbourne.txt
# 04-11-shanghai.txt
# 04-11-tokyo.txt
# 04-12-cairo.txt
# 04-12-karachi.txt
# 04-12-melbourne.txt
# 04-12-osaka.txt
# 04-12-shanghai.txt
# 04-12-singapore.txt
# 04-12-tokyo.txt
# 04-13-cairo.txt
# 04-13-jakarta.txt
# 04-13-manila.txt
# ...

# %% [markdown]
# Task 5

# %%
cities = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
          'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

cities_thing = os.path.join(base_folder, "cities")
os.makedirs(cities_thing, exist_ok=True)
if os.path.exists(cities_thing):
    print(f'{cities_thing} already exists')
else:
    os.mkdir(cities_thing)

for city in cities:
    path = os.path.join(cities_thing, city.lower())
    if os.path.exists(path):
        print(f"{path} already exists")
    else:
        os.mkdir(path)
        print(f"{path} created!")
# Out:
# C:\Users\PF3SC\OneDrive\Documents\GitHub\learning-portfolio-briana-tan\6.2_files,_folders_&_os__exercises\os-collaboration-exercise-data\cities already exists
# C:\Users\PF3SC\OneDrive\Documents\GitHub\learning-portfolio-briana-tan\6.2_files,_folders_&_os__exercises\os-collaboration-exercise-data\cities\cairo already exists
# C:\Users\PF3SC\OneDrive\Documents\GitHub\learning-portfolio-briana-tan\6.2_files,_folders_&_os__exercises\os-collaboration-exercise-data\cities\dhaka already exists
# C:\Users\PF3SC\OneDrive\Documents\GitHub\learning-portfolio-briana-tan\6.2_files,_folders_&_os__exercises\os-collaboration-exercise-data\cities\jakarta already exists
# C:\Users\PF3SC\OneDrive\Documents\GitHub\learning-portfolio-briana-tan\6.2_files,_folders_&_os__exercises\os-collaboration-exercise-data\cities\karachi already exists
# ...

# %% [markdown]
# Task 6

# %%
ccairo = glob.glob('os-collaboration-exercise-data/**cairo.txt',recursive = True)
print(ccairo)

def please_sort(name):
    filename = name.split('.')[0]
    city = filename.split('-')[-1]
    destination = os.path.join(cities_thing, city)
    return destination

for i in range(len(ccairo)):
    basename = os.path.basename(ccairo[i])
    newname = rename_my_file(basename)
    destin = please_sort(newname)
    full_dest = os.path.join(destin, newname)
    shutil.copy(ccairo[i], full_dest)
    print(f"{ccairo[i]} copied to {full_dest}")
# Out:
# ['os-collaboration-exercise-data\\apr-02_cairo.txt', 'os-collaboration-exercise-data\\apr-06_cairo.txt', 'os-collaboration-exercise-data\\apr-07_cairo.txt', 'os-collaboration-exercise-data\\apr-10_cairo.txt', 'os-collaboration-exercise-data\\apr-12_cairo.txt', 'os-collaboration-exercise-data\\apr-13_cairo.txt', 'os-collaboration-exercise-data\\apr-14_cairo.txt', 'os-collaboration-exercise-data\\apr-15_cairo.txt', 'os-collaboration-exercise-data\\apr-17_cairo.txt', 'os-collaboration-exercise-data\\apr-20_cairo.txt', 'os-collaboration-exercise-data\\apr-21_cairo.txt', 'os-collaboration-exercise-data\\apr-22_cairo.txt', 'os-collaboration-exercise-data\\apr-23_cairo.txt', 'os-collaboration-exercise-data\\apr-24_cairo.txt', 'os-collaboration-exercise-data\\aug-01_cairo.txt', 'os-collaboration-exercise-data\\aug-03_cairo.txt', 'os-collaboration-exercise-data\\aug-04_cairo.txt', 'os-collaboration-exercise-data\\aug-05_cairo.txt', 'os-collaboration-exercise-data\\aug-07_cairo.txt', 'os-colla
# ...

# %% [markdown]
# Task 7

# %%
base_folder = r"C:\Users\PF3SC\OneDrive\Documents\GitHub\learning-portfolio-briana-tan\6.2_files,_folders_&_os__exercises\os-collaboration-exercise-data"

oldfiles = glob.glob(os.path.join(base_folder,'*'))

months = {
    'jan': '01', 'feb': '02', 'mar': '03',
    'apr': '04', 'may': '05', 'jun': '06',
    'jul': '07', 'aug': '08', 'sep': '09',
    'oct': '10', 'nov': '11', 'dec': '12'
}

def rename_my_file(old_file_name):
    name, ext = os.path.splitext(old_file_name)
    monthword, rest = name.split('-')
    rest = rest.replace("_", "-")
    monthnumber = months[monthword]
    return f"{monthnumber}-{rest}{ext}"

cities = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
          'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

cities_thing = os.path.join(base_folder, "cities")
os.makedirs(cities_thing, exist_ok=True)
if os.path.exists(cities_thing):
    print(f'{cities_thing} already exists')
else:
    os.mkdir(cities_thing)

for city in cities:
    path = os.path.join(cities_thing, city.lower())
    if os.path.exists(path):
        print(f"{path} already exists")
    else:
        os.mkdir(path)
        print(f"{path} created!")

def please_sort(name):
    filename = name.split('.')[0]
    city = filename.split('-')[-1]
    destination = os.path.join(cities_thing, city)
    return destination

# task 5 and 7
for file in oldfiles:
    basename = os.path.basename(file)
    newname = rename_my_file(basename)
    destin = please_sort(newname)
    full_dest = os.path.join(destin, newname)
    shutil.copy(file, full_dest)
    print(f"{file} copied to {full_dest}")
# Out:
# C:\Users\PF3SC\OneDrive\Documents\GitHub\learning-portfolio-briana-tan\6.2_files,_folders_&_os__exercises\os-collaboration-exercise-data\cities already exists
# C:\Users\PF3SC\OneDrive\Documents\GitHub\learning-portfolio-briana-tan\6.2_files,_folders_&_os__exercises\os-collaboration-exercise-data\cities\cairo already exists
# C:\Users\PF3SC\OneDrive\Documents\GitHub\learning-portfolio-briana-tan\6.2_files,_folders_&_os__exercises\os-collaboration-exercise-data\cities\dhaka already exists
# C:\Users\PF3SC\OneDrive\Documents\GitHub\learning-portfolio-briana-tan\6.2_files,_folders_&_os__exercises\os-collaboration-exercise-data\cities\jakarta already exists
# C:\Users\PF3SC\OneDrive\Documents\GitHub\learning-portfolio-briana-tan\6.2_files,_folders_&_os__exercises\os-collaboration-exercise-data\cities\karachi already exists
# ...
